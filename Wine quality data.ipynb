# %%
import pandas as pd
import numpy as np

# %%
redwine = pd.read_csv("C:\\Users\\hp\\Desktop\\Python n DS\\winequality-red.csv", sep = ";")

# %%
whitewine = pd.read_csv("C:\\Users\\hp\\Desktop\\Python n DS\\winequality-white.csv", sep = ";")

# %%
redwine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
redwine.shape
# Out:
# (1599, 12)

# %%
redwine['color'] = 'Red'

# %%
redwine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   Red
# 1      9.8        5   Red
# ...

# %%
redwine['color1'] = ['Red' for i in range(0,1599)]

# %%
redwine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color color1
# 0      9.4        5   Red    Red
# ...

# %%
redwine.drop('color1',axis=1, inplace = True)

# %%
redwine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   Red
# 1      9.8        5   Red
# ...

# %%
whitewine['color'] = 'White'

# %%
whitewine.shape
# Out:
# (4898, 13)

# %%
whitewine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  color
# 0      8.8        6  White
# 1      9.5        6  White
# ...

# %%
pd.concat([redwine,whitewine], axis = 0, join = 'outer').head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   Red
# 1      9.8        5   Red
# ...

# %%
pd.concat([redwine,whitewine], axis = 1, join = 'outer').head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#   free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  ...    \
# 0                11.0                  34.0   0.9978  3.51       0.56  ...
# 1                25.0                  67.0   0.9968  3.20       0.68  ...
# 2                15.0                  54.0   0.9970  3.26       0.65  ...
# 3                17.0                  60.0   0.9980  3.16       0.58  ...
# 4                11.0                  34.0   0.9978  3.51       0.56  ...
#
# ...

# %%
output_data = pd.concat([redwine,whitewine], axis = 0, join = 'outer', keys = [1,2])

# %%
output_data[(output_data['color'] == 'Red') & (output_data['pH'] > 3.0)].head(10)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1 0            7.4              0.70         0.00             1.9      0.076
#   1            7.8              0.88         0.00             2.6      0.098
#   2            7.8              0.76         0.04             2.3      0.092
#   3           11.2              0.28         0.56             1.9      0.075
#   4            7.4              0.70         0.00             1.9      0.076
#   5            7.4              0.66         0.00             1.8      0.075
#   6            7.9              0.60         0.06             1.6      0.069
#   7            7.3              0.65         0.00             1.2      0.065
#   8            7.8              0.58         0.02             2.0      0.073
#   9            7.5              0.50         0.36             6.1      0.071
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
output_data.sort_values('pH', ascending = False).head(10)
# Out:
#         fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1 1316            5.4             0.740         0.00            1.20
#   1321            5.0             0.740         0.00            1.20
#   695             5.1             0.470         0.02            1.30
#   45              4.6             0.520         0.15            2.10
#   95              4.7             0.600         0.17            2.30
# 2 1250            5.3             0.260         0.23            5.15
#   1255            6.4             0.220         0.34            1.80
#   2771            6.3             0.200         0.24            1.70
#   2036            5.7             0.270         0.32            1.20
#   2321            4.6             0.445         0.00            1.40
#
#         chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 1 1316      0.041                 16.0                  46.0  0.99258  4.01
# ...

# %%
output_data[(output_data['color'] == 'Red') & (output_data['pH'] > 4)].head()
# Out:
#         fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1 1316            5.4              0.74          0.0             1.2
#   1321            5.0              0.74          0.0             1.2
#
#         chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 1 1316      0.041                 16.0                  46.0  0.99258  4.01
#   1321      0.041                 16.0                  46.0  0.99258  4.01
#
#         sulphates  alcohol  quality color
# 1 1316       0.59     12.5        6   Red
#   1321       0.59     12.5        6   Red
